# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
df = pd.read_csv('car_purchasing.csv', encoding='ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %%
df.head()
# Out:
#          age  annual Salary  credit card debt    net worth  \
# 0  41.851720    62812.09301      11609.380910  238961.2505
# 1  40.870623    66646.89292       9572.957136  530973.9078
# 2  43.152897    53798.55112      11160.355060  638467.1773
# 3  58.271369    79370.03798      14426.164850  548599.0524
# 4  57.313749    59729.15130       5358.712177  560304.0671
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  500 non-null    float64
#  1   annual Salary        500 non-null    float64
#  2   credit card debt     500 non-null    float64
#  3   net worth            500 non-null    float64
#  4   car purchase amount  500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
plt.scatter(df['annual Salary'] , df['credit card debt'])
plt.xlabel('annual Salary')
plt.ylabel('credit card debt')
plt.title('the corr between credit card debt and annual Salary')
# Out:
# Text(0.5, 1.0, 'the corr between credit card debt and annual Salary')

# %%
sns.pairplot(df)

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
#Trying linear regression
lreg = LinearRegression()
lreg.fit(X_train, y_train)
print('Train score', lreg.score(X_train, y_train))
print('Test score', lreg.score(X_test, y_test))
# Out:
# Train score 0.9999999826937988
# Test score 0.9999999736024259

# %%
y_pred = lreg.predict(X_test)

# %%
ann = Sequential([Dense(32, activation="relu"),
                 Dense(1, activation='linear')])

ann.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['mean_absolute_error'])


history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 27ms/step - loss: 0.1746 - mean_absolute_error: 0.3924 - val_loss: 0.1384 - val_mean_absolute_error: 0.3423
# Epoch 2/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0949 - mean_absolute_error: 0.2780 - val_loss: 0.0707 - val_mean_absolute_error: 0.2317
# Epoch 3/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0453 - mean_absolute_error: 0.1821 - val_loss: 0.0326 - val_mean_absolute_error: 0.1473
# Epoch 4/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0216 - mean_absolute_error: 0.1196 - val_loss: 0.0167 - val_mean_absolute_error: 0.1047
# Epoch 5/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0136 - mean_absolute_error: 0.0933 - val_loss: 0.0130 - val_mean_absolute_error: 0.0946
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0125 - mean_absolute_error: 0.0886 - val_loss: 0.0121 - val_mean_absolute_error: 0.0903
# Epoch 7/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mean_absolute_error: 0.0848 - val_loss: 0.0113 - val_mean_absolute_error: 0.0874
# Epoch 8/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0106 - mean_absolute_error: 0.0803 - val_loss: 0.0107 - val_mean_absolute_error: 0.0852
# Epoch 9/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0097 - mean_absolute_error: 0.0768 - val_loss: 0.0101 - val_mean_absolute_error: 0.0828
# Epoch 10/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0090 - mean_absolute_error: 0.0739 - val_loss: 0.0096 - val_mean_absolute_error: 0.0805
# Epoch 11/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0084 - mean_absolute_error: 0.0708 - val_loss: 0.0091 - val_mean_absolute_error: 0.0780
# Epoch 12/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0078 - mean_absolute_error: 0.0681 - val_loss: 0.0086 - val_mean_absolute_error: 0.0760
# Epoch 13/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0073 - mean_absolute_error: 0.0656 - val_loss: 0.0083 - val_mean_absolute_error: 0.0750
# Epoch 14/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0068 - mean_absolute_error: 0.0633 - val_loss: 0.0080 - val_mean_absolute_error: 0.0739
# Epoch 15/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0062 - mean_absolute_error: 0.0609 - val_loss: 0.0076 - val_mean_absolute_error: 0.0726
# Epoch 16/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0058 - mean_absolute_error: 0.0586 - val_loss: 0.0072 - val_mean_absolute_error: 0.0712
# Epoch 17/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_absolute_error: 0.0571 - val_loss: 0.0068 - val_mean_absolute_error: 0.0691
# Epoch 18/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0051 - mean_absolute_error: 0.0558 - val_loss: 0.0065 - val_mean_absolute_error: 0.0675
# Epoch 19/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0049 - mean_absolute_error: 0.0546 - val_loss: 0.0061 - val_mean_absolute_error: 0.0655
# Epoch 20/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0047 - mean_absolute_error: 0.0536 - val_loss: 0.0059 - val_mean_absolute_error: 0.0641
# Epoch 21/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0045 - mean_absolute_error: 0.0527 - val_loss: 0.0057 - val_mean_absolute_error: 0.0629
# Epoch 22/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0043 - mean_absolute_error: 0.0516 - val_loss: 0.0054 - val_mean_absolute_error: 0.0612
# Epoch 23/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0041 - mean_absolute_error: 0.0507 - val_loss: 0.0051 - val_mean_absolute_error: 0.0595
# Epoch 24/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0040 - mean_absolute_error: 0.0500 - val_loss: 0.0049 - val_mean_absolute_error: 0.0578
# Epoch 25/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0038 - mean_absolute_error: 0.0487 - val_loss: 0.0047 - val_mean_absolute_error: 0.0568
# Epoch 26/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0036 - mean_absolute_error: 0.0475 - val_loss: 0.0044 - val_mean_absolute_error: 0.0548
# Epoch 27/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0034 - mean_absolute_error: 0.0466 - val_loss: 0.0042 - val_mean_absolute_error: 0.0533
# Epoch 28/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0033 - mean_absolute_error: 0.0457 - val_loss: 0.0040 - val_mean_absolute_error: 0.0520
# Epoch 29/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0031 - mean_absolute_error: 0.0446 - val_loss: 0.0038 - val_mean_absolute_error: 0.0506
# Epoch 30/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0030 - mean_absolute_error: 0.0435 - val_loss: 0.0036 - val_mean_absolute_error: 0.0494
# Epoch 31/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0029 - mean_absolute_error: 0.0426 - val_loss: 0.0034 - val_mean_absolute_error: 0.0482
# Epoch 32/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0027 - mean_absolute_error: 0.0416 - val_loss: 0.0032 - val_mean_absolute_error: 0.0468
# Epoch 33/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0026 - mean_absolute_error: 0.0407 - val_loss: 0.0031 - val_mean_absolute_error: 0.0454
# Epoch 34/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0025 - mean_absolute_error: 0.0396 - val_loss: 0.0029 - val_mean_absolute_error: 0.0441
# Epoch 35/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0023 - mean_absolute_error: 0.0386 - val_loss: 0.0027 - val_mean_absolute_error: 0.0427
# Epoch 36/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0022 - mean_absolute_error: 0.0376 - val_loss: 0.0025 - val_mean_absolute_error: 0.0416
# Epoch 37/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0021 - mean_absolute_error: 0.0365 - val_loss: 0.0024 - val_mean_absolute_error: 0.0403
# Epoch 38/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0020 - mean_absolute_error: 0.0356 - val_loss: 0.0022 - val_mean_absolute_error: 0.0389
# Epoch 39/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0019 - mean_absolute_error: 0.0346 - val_loss: 0.0021 - val_mean_absolute_error: 0.0375
# Epoch 40/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0017 - mean_absolute_error: 0.0334 - val_loss: 0.0019 - val_mean_absolute_error: 0.0361
# Epoch 41/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0016 - mean_absolute_error: 0.0324 - val_loss: 0.0018 - val_mean_absolute_error: 0.0349
# Epoch 42/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0313 - val_loss: 0.0016 - val_mean_absolute_error: 0.0334
# Epoch 43/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0014 - mean_absolute_error: 0.0302 - val_loss: 0.0015 - val_mean_absolute_error: 0.0320
# Epoch 44/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0013 - mean_absolute_error: 0.0292 - val_loss: 0.0014 - val_mean_absolute_error: 0.0304
# Epoch 45/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0012 - mean_absolute_error: 0.0282 - val_loss: 0.0013 - val_mean_absolute_error: 0.0295
# Epoch 46/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0011 - mean_absolute_error: 0.0269 - val_loss: 0.0011 - val_mean_absolute_error: 0.0275
# Epoch 47/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0010 - mean_absolute_error: 0.0261 - val_loss: 0.0010 - val_mean_absolute_error: 0.0262
# Epoch 48/50
# 10/10 [==============================] - 0s 11ms/step - loss: 9.2000e-04 - mean_absolute_error: 0.0246 - val_loss: 9.0119e-04 - val_mean_absolute_error: 0.0247
# Epoch 49/50
# 10/10 [==============================] - 0s 20ms/step - loss: 8.5335e-04 - mean_absolute_error: 0.0236 - val_loss: 8.4182e-04 - val_mean_absolute_error: 0.0237
# Epoch 50/50
# 10/10 [==============================] - 0s 25ms/step - loss: 7.5223e-04 - mean_absolute_error: 0.0223 - val_loss: 7.2672e-04 - val_mean_absolute_error: 0.0222

# %%
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmin(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
ann_y_pred = ann.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
r2 = r2_score(y_test, y_pred)
print('R2 score:', r2)
# Out:
# R2 score: 0.9999999736024259

# %%
ann.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 7.8290e-04 - mean_absolute_error: 0.0216
# [0.0007829038077034056, 0.021629393100738525]

# %%
ann.predict([[40, 70000.500, 9550,534000]])
# Out:
# 1/1 [==============================] - 0s 55ms/step
# array([[62744.105]], dtype=float32)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='Linear Regression')
plt.scatter(y_test, ann_y_pred, label='ANN')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.legend()
plt.show()

# %%
# konvert data dari kontinu ke binary
y_test_binary = (y_test >= 0.5).astype(int)

# %%
# Predicting the test set results
y_pred_binary = lreg.predict(X_test)
y_pred_binary = (y_pred_binary > 0.5).astype(int)  # Mengonversi prediksi ke biner

# %%
# confusion matrix
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test_binary, y_pred_binary)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <Axes: >

# %%
# classification report
print(classification_report(y_test_binary, y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        47
#            1       1.00      1.00      1.00        53
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
